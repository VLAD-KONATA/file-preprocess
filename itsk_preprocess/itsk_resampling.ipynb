# %%
import os
import SimpleITK as sitk
import shutil
 
def resampleVolume(outspacing, vol):
    """
    将体数据重采样的指定的spacing大小\n
    paras：
    outpacing：指定的spacing，例如[1,1,1]
    vol：sitk读取的image信息，这里是体数据\n
    return：重采样后的数据
    """
    outsize = [0, 0, 0]
    # 读取文件的size和spacing信息
    inputsize = vol.GetSize()
    inputspacing = vol.GetSpacing()
 
    transform = sitk.Transform()
    transform.SetIdentity()
    # 计算改变spacing后的size，用物理尺寸/体素的大小
    outsize[0] = round(inputsize[0] * inputspacing[0] / outspacing[0])
    outsize[1] = round(inputsize[1] * inputspacing[1] / outspacing[1])
    outsize[2] = round(inputsize[2] * inputspacing[2] / outspacing[2])
 
    # 设定重采样的一些参数
    resampler = sitk.ResampleImageFilter()
    resampler.SetTransform(transform)
    resampler.SetInterpolator(sitk.sitkLinear)
    resampler.SetOutputOrigin(vol.GetOrigin())
    resampler.SetOutputSpacing(outspacing)
    resampler.SetOutputDirection(vol.GetDirection())
    resampler.SetSize(outsize)
    newvol = resampler.Execute(vol)
    return newvol

# %%
if __name__ == '__main__':
    baseDir = r'/home/konata/Dataset/TAO_CT/50-50'
    objDir = r'/home/konata/Dataset/TAO_CT/50-50'
    outspacing_0 = 0.4883
    outspacing_1 = 0.4883
    outspacing_2 = 1
    
    #I_vol_list = ['reg_ADC.nii.gz', 'reg_DWI_0.nii.gz', 'reg_DWI_800.nii.gz', 'reg_T1C.nii.gz', 'T2.nii.gz']
 
    if os.path.exists(baseDir):
        files=os.listdir(baseDir)
        files=['3546828_2020-01-03.nii.gz']
        for file in files:
            img_dir=os.path.join(baseDir+"/"+file)
            resampled_img_dir = objDir +"/"+file
            img_ori = sitk.Image(sitk.ReadImage(img_dir))
            img_ori_spacing = img_ori.GetSpacing()
            #outspacing_2 = img_ori_spacing[2]
            outspacing = [outspacing_0, outspacing_1, outspacing_2]
 
            img_resampled = resampleVolume(outspacing, img_ori)
            sitk.WriteImage(img_resampled, resampled_img_dir)
            print('pid_', file, ' transformed!')
# Out:
# pid_ 3546828_2020-01-03.nii.gz  transformed!

# %%
if __name__ == '__main__':
    baseDir = r'/home/konata/Dataset/TAO_CT/正常'
    objDir = r'/home/konata/Dataset/TAO_CT/正常'
    outspacing_0 = 0.4883
    outspacing_1 = 0.4883
    outspacing_2 = 1
    
    #I_vol_list = ['reg_ADC.nii.gz', 'reg_DWI_0.nii.gz', 'reg_DWI_800.nii.gz', 'reg_T1C.nii.gz', 'T2.nii.gz']
    folders=os.listdir(baseDir)
    for folder in folders:
        path=os.path.join(baseDir,folder)
        if os.path.exists(path):
            files=os.listdir(path)
            for file in files:
                print('pid_', file, ' transforming...!')
                img_dir=os.path.join(path,file)
                resampled_img_dir = os.path.join(objDir,folder,file)
                try:
                    img_ori = sitk.Image(sitk.ReadImage(img_dir))
                    img_ori_spacing = img_ori.GetSpacing()
                    #outspacing_2 = img_ori_spacing[2]
                    outspacing = [outspacing_0, outspacing_1, outspacing_2]
        
                    img_resampled = resampleVolume(outspacing, img_ori)
                    sitk.WriteImage(img_resampled, resampled_img_dir)
                except:
                    shutil.move(img_dir,'/home/konata/Dataset/TAO_CT/ERROR/'+file)
                print('pid_', file, ' transformed!')
# Out:
# pid_ 3781154_2020-12-17a.nii.gz  transforming...!
# pid_ 3781154_2020-12-17a.nii.gz  transformed!
# pid_ 3781154_2020-12-17b.nii.gz  transforming...!
# pid_ 3781154_2020-12-17b.nii.gz  transformed!
# pid_ 2687511_2020-06-22.nii.gz  transforming...!
# pid_ 2687511_2020-06-22.nii.gz  transformed!
# pid_ 2687511_2020-06-22b.nii.gz  transforming...!
# pid_ 2687511_2020-06-22b.nii.gz  transformed!
# pid_ 2687511_2020-06-22c.nii.gz  transforming...!
# pid_ 2687511_2020-06-22c.nii.gz  transformed!
# pid_ 3754305_2020-11-13b.nii.gz  transforming...!
# pid_ 3754305_2020-11-13b.nii.gz  transformed!
# pid_ 3754305_2020-11-13.nii.gz  transforming...!
# pid_ 3754305_2020-11-13.nii.gz  transformed!
# pid_ 3754305_2020-11-13a.nii.gz  transforming...!
# pid_ 3754305_2020-11-13a.nii.gz  transformed!
# pid_ 3775589_2020-12-10.nii.gz  transforming...!
# pid_ 3775589_2020-12-10.nii.gz  transformed!
# pid_ 3775589_2020-12-10b.nii.gz  transforming...!
# pid_ 3775589_2020-12-10b.nii.gz  transformed!
# pid_ 3724643_2020-11-05.nii.gz  transforming...!
# pid_ 3724643_2020-11-05.nii.gz  transformed!
# pid_ 3724643_2020-11-05a.nii.gz  transforming...!
# pid_ 3724643_2020-11-05a.nii.gz  transformed!
# pid_ 3724643_2020-11-05d.nii.gz  transforming...!
# pid_ 3724643_2020-11-05d.nii.gz  transformed!
# pid_ 3574185_2020-03-20a.nii.gz  transforming...!
# pid_ 3574185_2020-03-20a.nii.gz  transformed!
# pid_ 3574185_2020-03-20.nii.gz  transforming...!
# pid_ 3574185_2020-03-20.nii.gz  transformed!
# pid_ 3624295_2020-06-03.nii.gz  transforming...!
# pid_ 3624295_2020-06-03.nii.gz  transformed!
# pid_ 3624295_2020-06-03c.nii.gz  transforming...!
# pid_ 3624295_2020-06-03c.nii.gz  transformed!
# pid_ 2704933_2020-11-10a.nii.gz  transforming...!
# pid_ 2704933_2020-11-10a.nii.gz  transformed!
# pid_ 2704933_2020-11-10c.nii.gz  transforming...!
# pid_ 2704933_2020-11-10c.nii.gz  transformed!
# pid_ 2704933_2020-11-10b.nii.gz  transforming...!
# pid_ 2704933_2020-11-10b.nii.gz  transformed!
# pid_ 3561193_2020-01-20b.nii.gz  transforming...!
# pid_ 3561193_2020-01-20b.nii.gz  transformed!
# pid_ 3561193_2020-01-20c.nii.gz  transforming...!
# pid_ 3561193_2020-01-20c.nii.gz  transformed!
# pid_ 3565738_2020-02-13.nii.gz  transforming...!
# pid_ 3565738_2020-02-13.nii.gz  transformed!
# pid_ 3565738_2020-02-13b.nii.gz  transforming...!
# pid_ 3565738_2020-02-13b.nii.gz  transformed!
# pid_ 3565738_2020-02-13c.nii.gz  transforming...!
# pid_ 3565738_2020-02-13c.nii.gz  transformed!
# pid_ 3565738_2020-02-13d.nii.gz  transforming...!
# pid_ 3565738_2020-02-13d.nii.gz  transformed!
# pid_ 3595099_2020-04-23.nii.gz  transforming...!
# pid_ 3595099_2020-04-23.nii.gz  transformed!
# pid_ 3595099_2020-04-23c.nii.gz  transforming...!
# pid_ 3595099_2020-04-23c.nii.gz  transformed!
# pid_ 3750035_2020-11-09a.nii.gz  transforming...!
# pid_ 3750035_2020-11-09a.nii.gz  transformed!
# pid_ 3750035_2020-11-09.nii.gz  transforming...!
# pid_ 3750035_2020-11-09.nii.gz  transformed!
# pid_ 3750035_2020-11-09b.nii.gz  transforming...!
# pid_ 3750035_2020-11-09b.nii.gz  transformed!
# pid_ 3708106_2020-09-15c.nii.gz  transforming...!
# pid_ 3708106_2020-09-15c.nii.gz  transformed!
# pid_ 3708106_2020-09-15b.nii.gz  transforming...!
# pid_ 3708106_2020-09-15b.nii.gz  transformed!
# pid_ 3708106_2020-09-15d.nii.gz  transforming...!
# pid_ 3708106_2020-09-15d.nii.gz  transformed!
# pid_ 3640932_2020-06-28c.nii.gz  transforming...!
# pid_ 3640932_2020-06-28c.nii.gz  transformed!
# pid_ 3640932_2020-06-28.nii.gz  transforming...!
# pid_ 3640932_2020-06-28.nii.gz  transformed!
# pid_ 3552195_2020-01-09.nii.gz  transforming...!
# pid_ 3552195_2020-01-09.nii.gz  transformed!
# pid_ 3552195_2020-01-09a.nii.gz  transforming...!
# pid_ 3552195_2020-01-09a.nii.gz  transformed!
# pid_ 3552195_2020-01-09b.nii.gz  transforming...!
# pid_ 3552195_2020-01-09b.nii.gz  transformed!
# pid_ 3756931_2020-11-16b.nii.gz  transforming...!
# pid_ 3756931_2020-11-16b.nii.gz  transformed!
# pid_ 3756931_2020-11-16a.nii.gz  transforming...!
# pid_ 3756931_2020-11-16a.nii.gz  transformed!
# pid_ 3770844_2020-12-04a.nii.gz  transforming...!
# pid_ 3770844_2020-12-04a.nii.gz  transformed!
# pid_ 3770844_2020-12-04c.nii.gz  transforming...!
# pid_ 3770844_2020-12-04c.nii.gz  transformed!
# pid_ 3770844_2020-12-04.nii.gz  transforming...!
# pid_ 3770844_2020-12-04.nii.gz  transformed!
# pid_ 3462361_2020-11-14a.nii.gz  transforming...!
# pid_ 3462361_2020-11-14a.nii.gz  transformed!
# pid_ 3462361_2020-11-14e.nii.gz  transforming...!
# pid_ 3462361_2020-11-14e.nii.gz  transformed!
# pid_ 3462361_2020-11-14b.nii.gz  transforming...!
# pid_ 3462361_2020-11-14b.nii.gz  transformed!
# pid_ 3462361_2020-11-14g.nii.gz  transforming...!
# pid_ 3462361_2020-11-14g.nii.gz  transformed!
# pid_ 3785378_2020-12-23a.nii.gz  transforming...!
# pid_ 3785378_2020-12-23a.nii.gz  transformed!
# pid_ 3785378_2020-12-23.nii.gz  transforming...!
# pid_ 3785378_2020-12-23.nii.gz  transformed!
# pid_ 3785378_2020-12-23b.nii.gz  transforming...!
# pid_ 3785378_2020-12-23b.nii.gz  transformed!
# pid_ 3761870_2020-11-23a.nii.gz  transforming...!
# pid_ 3761870_2020-11-23a.nii.gz  transformed!
# pid_ 3761870_2020-11-23b.nii.gz  transforming...!
# pid_ 3664143_2020-09-11d.nii.gz  transforming...!
# pid_ 3664143_2020-09-11d.nii.gz  transformed!
# pid_ 3647035_2020-07-06d.nii.gz  transforming...!
# pid_ 3647035_2020-07-06d.nii.gz  transformed!
# pid_ 3647035_2020-07-06b.nii.gz  transforming...!
# pid_ 3647035_2020-07-06b.nii.gz  transformed!
# pid_ 3647035_2020-07-06c.nii.gz  transforming...!
# pid_ 3647035_2020-07-06c.nii.gz  transformed!
# pid_ 3721248_2020-10-03d.nii.gz  transforming...!
# pid_ 3721248_2020-10-03d.nii.gz  transformed!
# pid_ 3721248_2020-10-03g.nii.gz  transforming...!
# pid_ 3721248_2020-10-03g.nii.gz  transformed!
# pid_ 3721248_2020-10-03b.nii.gz  transforming...!
# pid_ 3721248_2020-10-03b.nii.gz  transformed!
# pid_ 3721248_2020-10-03c.nii.gz  transforming...!
# pid_ 3721248_2020-10-03c.nii.gz  transformed!
# pid_ 3721248_2020-10-03e.nii.gz  transforming...!
# pid_ 3721248_2020-10-03e.nii.gz  transformed!
# pid_ 3591465_2020-04-19a.nii.gz  transforming...!
# pid_ 3591465_2020-04-19a.nii.gz  transformed!
# pid_ 3591465_2020-04-19b.nii.gz  transforming...!
# pid_ 3591465_2020-04-19b.nii.gz  transformed!
# pid_ 3591465_2020-04-19.nii.gz  transforming...!
# pid_ 3591465_2020-04-19.nii.gz  transformed!
# pid_ 3764350_2020-11-25a.nii.gz  transforming...!
# pid_ 3764350_2020-11-25a.nii.gz  transformed!
# pid_ 3764350_2020-11-25c.nii.gz  transforming...!
# pid_ 3764350_2020-11-25c.nii.gz  transformed!
# pid_ 3764350_2020-11-25.nii.gz  transforming...!
# pid_ 3764350_2020-11-25.nii.gz  transformed!
# pid_ 3345571_2020-12-09.nii.gz  transforming...!
# pid_ 3345571_2020-12-09.nii.gz  transformed!
# pid_ 3345571_2020-12-09b.nii.gz  transforming...!
# pid_ 3345571_2020-12-09b.nii.gz  transformed!
# pid_ 3676504_2020-09-15d.nii.gz  transforming...!
# pid_ 3676504_2020-09-15d.nii.gz  transformed!
# pid_ 3676504_2020-09-15b.nii.gz  transforming...!
# pid_ 3676504_2020-09-15b.nii.gz  transformed!
# pid_ 3676504_2020-09-15c.nii.gz  transforming...!
# pid_ 3676504_2020-09-15c.nii.gz  transformed!
# pid_ 3597572_2020-04-27a.nii.gz  transforming...!
# pid_ 3597572_2020-04-27a.nii.gz  transformed!
# pid_ 3597572_2020-04-27.nii.gz  transforming...!
# pid_ 3597572_2020-04-27.nii.gz  transformed!
# pid_ 3597572_2020-04-27c.nii.gz  transforming...!
# pid_ 3597572_2020-04-27c.nii.gz  transformed!
# pid_ 3570733_2020-03-11.nii.gz  transforming...!
# pid_ 3570733_2020-03-11.nii.gz  transformed!
# pid_ 3570733_2020-03-11c.nii.gz  transforming...!
# pid_ 3570733_2020-03-11c.nii.gz  transformed!
# pid_ 3375268_2020-09-29.nii.gz  transforming...!
# pid_ 3375268_2020-09-29.nii.gz  transformed!
# pid_ 3375268_2020-09-29a.nii.gz  transforming...!
# pid_ 3375268_2020-09-29a.nii.gz  transformed!
# pid_ 3375268_2020-09-29b.nii.gz  transforming...!
# pid_ 3375268_2020-09-29b.nii.gz  transformed!
# pid_ 3679370_2020-08-12.nii.gz  transforming...!
# pid_ 3679370_2020-08-12.nii.gz  transformed!
# pid_ 3679370_2020-08-12c.nii.gz  transforming...!
# pid_ 3679370_2020-08-12c.nii.gz  transformed!
# pid_ 3764136_2020-11-25a.nii.gz  transforming...!
# pid_ 3764136_2020-11-25a.nii.gz  transformed!
# pid_ 3764136_2020-11-25b.nii.gz  transforming...!
# pid_ 3764136_2020-11-25b.nii.gz  transformed!
# pid_ 3578975_2020-04-02b.nii.gz  transforming...!
# pid_ 3578975_2020-04-02b.nii.gz  transformed!
# pid_ 3578975_2020-04-02c.nii.gz  transforming...!
# pid_ 3578975_2020-04-02c.nii.gz  transformed!
# pid_ 3578975_2020-04-02.nii.gz  transforming...!
# pid_ 3578975_2020-04-02.nii.gz  transformed!
# pid_ 3641418_2020-06-28b.nii.gz  transforming...!
# pid_ 3641418_2020-06-28b.nii.gz  transformed!
# pid_ 3641418_2020-06-28c.nii.gz  transforming...!
# pid_ 3641418_2020-06-28c.nii.gz  transformed!
# pid_ 3641418_2020-06-28.nii.gz  transforming...!
# pid_ 3641418_2020-06-28.nii.gz  transformed!
# pid_ 3757934_2020-11-17.nii.gz  transforming...!
# pid_ 3757934_2020-11-17.nii.gz  transformed!
# pid_ 3757934_2020-11-17a.nii.gz  transforming...!
# pid_ 3757934_2020-11-17a.nii.gz  transformed!
# pid_ 3757934_2020-11-17c.nii.gz  transforming...!
# pid_ 3757934_2020-11-17c.nii.gz  transformed!
# pid_ 3603626_2020-05-06d.nii.gz  transforming...!
# pid_ 3603626_2020-05-06d.nii.gz  transformed!
# pid_ 3603626_2020-05-06c.nii.gz  transforming...!
# pid_ 3603626_2020-05-06c.nii.gz  transformed!
# pid_ 3603626_2020-05-06.nii.gz  transforming...!
# pid_ 3603626_2020-05-06.nii.gz  transformed!
# pid_ 3765362_2020-11-26.nii.gz  transforming...!
# pid_ 3765362_2020-11-26.nii.gz  transformed!
# pid_ 3765362_2020-11-26b.nii.gz  transforming...!
# pid_ 3765362_2020-11-26b.nii.gz  transformed!
# pid_ 3765362_2020-11-26a.nii.gz  transforming...!
# pid_ 3765362_2020-11-26a.nii.gz  transformed!
# pid_ 3607891_2020-05-13c.nii.gz  transforming...!
# pid_ 3607891_2020-05-13c.nii.gz  transformed!
# pid_ 3607891_2020-05-13.nii.gz  transforming...!
# pid_ 3607891_2020-05-13.nii.gz  transformed!
# pid_ 3606763_2020-05-11.nii.gz  transforming...!
# pid_ 3606763_2020-05-11.nii.gz  transformed!
# pid_ 3606763_2020-05-11b.nii.gz  transforming...!
# pid_ 3606763_2020-05-11b.nii.gz  transformed!
# pid_ 3603623_2020-05-06c.nii.gz  transforming...!
# pid_ 3603623_2020-05-06c.nii.gz  transformed!
# pid_ 3603623_2020-05-06b.nii.gz  transforming...!
# pid_ 3603623_2020-05-06b.nii.gz  transformed!
# pid_ 3758908_2020-11-18c.nii.gz  transforming...!
# pid_ 3758908_2020-11-18c.nii.gz  transformed!
# pid_ 3758908_2020-11-18b.nii.gz  transforming...!
# pid_ 3758908_2020-11-18b.nii.gz  transformed!
# pid_ 3758908_2020-11-18a.nii.gz  transforming...!
# pid_ 3758908_2020-11-18a.nii.gz  transformed!
# pid_ 3567328_2020-02-25.nii.gz  transforming...!
# pid_ 3567328_2020-02-25.nii.gz  transformed!
# pid_ 3567328_2020-02-25b.nii.gz  transforming...!
# pid_ 3567328_2020-02-25b.nii.gz  transformed!
# pid_ 3774831_2020-12-09b.nii.gz  transforming...!
# pid_ 3774831_2020-12-09b.nii.gz  transformed!
# pid_ 3774831_2020-12-09a.nii.gz  transforming...!
# pid_ 3774831_2020-12-09a.nii.gz  transformed!
# pid_ 3772970_2020-12-07a.nii.gz  transforming...!
# pid_ 3772970_2020-12-07a.nii.gz  transformed!
# pid_ 3772970_2020-12-07c.nii.gz  transforming...!
# pid_ 3772970_2020-12-07c.nii.gz  transformed!
# pid_ 3737933_2020-10-24a.nii.gz  transforming...!
# pid_ 3737933_2020-10-24a.nii.gz  transformed!
# pid_ 3737933_2020-10-24.nii.gz  transforming...!
# pid_ 3737933_2020-10-24.nii.gz  transformed!
# pid_ 3737933_2020-10-24e.nii.gz  transforming...!
# pid_ 3737933_2020-10-24e.nii.gz  transformed!
# pid_ 3603649_2020-05-06.nii.gz  transforming...!
# pid_ 3603649_2020-05-06.nii.gz  transformed!
# pid_ 3603649_2020-05-06c.nii.gz  transforming...!
# pid_ 3603649_2020-05-06c.nii.gz  transformed!
# pid_ 3603649_2020-05-06d.nii.gz  transforming...!
# pid_ 3603649_2020-05-06d.nii.gz  transformed!
# pid_ 3582693_2020-04-07.nii.gz  transforming...!
# pid_ 3582693_2020-04-07.nii.gz  transformed!
# pid_ 3582693_2020-04-07a.nii.gz  transforming...!
# pid_ 3582693_2020-04-07a.nii.gz  transformed!
# pid_ 3582693_2020-04-07b.nii.gz  transforming...!
# pid_ 3582693_2020-04-07b.nii.gz  transformed!
# pid_ 3785286_2020-12-23a.nii.gz  transforming...!
# pid_ 3785286_2020-12-23a.nii.gz  transformed!
# pid_ 3785286_2020-12-23d.nii.gz  transforming...!
# pid_ 3785286_2020-12-23d.nii.gz  transformed!
# pid_ 3785286_2020-12-23b.nii.gz  transforming...!
# pid_ 3785286_2020-12-23b.nii.gz  transformed!
# pid_ 1399633_2020-04-16.nii.gz  transforming...!
# pid_ 1399633_2020-04-16.nii.gz  transformed!
# pid_ 1399633_2020-04-16c.nii.gz  transforming...!
# pid_ 1399633_2020-04-16c.nii.gz  transformed!
# pid_ 3599515_2020-04-29.nii.gz  transforming...!
# pid_ 3599515_2020-04-29.nii.gz  transformed!
# pid_ 3599515_2020-04-29a.nii.gz  transforming...!
# pid_ 3599515_2020-04-29a.nii.gz  transformed!

# %%
if __name__ == '__main__':
    baseDir = r'/home/konata/Dataset/TED_MRI/T2/mask/origin'
    objDir = '/home/konata/Dataset/TED_MRI/T2/mask/origin_re'
    outspacing_0 = 0.5
    outspacing_1 = 0.5
    outspacing_2 = 1
    
    #I_vol_list = ['reg_ADC.nii.gz', 'reg_DWI_0.nii.gz', 'reg_DWI_800.nii.gz', 'reg_T1C.nii.gz', 'T2.nii.gz']
 
    if os.path.exists(baseDir):

        imgs_list = os.listdir(baseDir)

        for img in imgs_list:
            #if img in I_vol_list:
            img_dir = baseDir +'/' + img
            resampled_img_dir = objDir +'/'+ img

            img_ori = sitk.Image(sitk.ReadImage(img_dir))
            img_ori_spacing = img_ori.GetSpacing()
            #outspacing_2 = img_ori_spacing[2]
            outspacing = [outspacing_0, outspacing_1, outspacing_2]

            img_resampled = resampleVolume(outspacing, img_ori)
            sitk.WriteImage(img_resampled, resampled_img_dir)
            print('pid_ ', img, ' transformed!')
# Out:
# pid_  637_2020-05-11.nii.gz  transformed!
# pid_  683_2020-06-16.nii.gz  transformed!
# pid_  430_2019-04-09.nii.gz  transformed!
# pid_  681_2020-06-12.nii.gz  transformed!
# pid_  440_2018-11-29.nii.gz  transformed!
# pid_  1656_2021-05-13.nii.gz  transformed!
# pid_  36_2019-05-09.nii.gz  transformed!
# pid_  740_2020-07-13.nii.gz  transformed!
# pid_  886_2020-08-06.nii.gz  transformed!
# pid_  1142_2021-03-04.nii.gz  transformed!
# pid_  516_2018-02-13.nii.gz  transformed!
# pid_  199_2019-05-16.nii.gz  transformed!
# pid_  1265_2021-05-07.nii.gz  transformed!
# pid_  748_2020-08-03.nii.gz  transformed!
# pid_  482_2018-11-08.nii.gz  transformed!
# pid_  460_2017-10-20.nii.gz  transformed!
# pid_  1645_2021-05-15.nii.gz  transformed!
# pid_  495_2019-06-18.nii.gz  transformed!
# pid_  788_2020-08-14.nii.gz  transformed!
# pid_  976_2020-11-13.nii.gz  transformed!
# pid_  1247_2021-02-19.nii.gz  transformed!
# pid_  1248_2021-05-04.nii.gz  transformed!
# pid_  570_2018-05-30.nii.gz  transformed!
# pid_  1520_2021-05-30.nii.gz  transformed!
# pid_  1015_2021-03-23.nii.gz  transformed!
# pid_  1630_2021-05-11.nii.gz  transformed!
# pid_  522_2019-01-30.nii.gz  transformed!
# pid_  162_2019-08-15.nii.gz  transformed!
# pid_  391_2018-02-08.nii.gz  transformed!
# pid_  1477_2021-09-18.nii.gz  transformed!
# pid_  198_2019-11-20.nii.gz  transformed!
# pid_  1668_2021-06-26.nii.gz  transformed!
# pid_  984_2020-11-19.nii.gz  transformed!
# pid_  653_2019-12-04.nii.gz  transformed!
# pid_  452_2018-11-20.nii.gz  transformed!
# pid_  443_2019-03-21.nii.gz  transformed!
# pid_  336_2020-03-26.nii.gz  transformed!
# pid_  127_2019-09-04.nii.gz  transformed!
# pid_  673_2020-06-05.nii.gz  transformed!
# pid_  1093_2021-02-09.nii.gz  transformed!
# pid_  191_2019-11-20.nii.gz  transformed!
# pid_  992_2020-11-12.nii.gz  transformed!
# pid_  1657_2021-07-06.nii.gz  transformed!
# pid_  1385_2021-06-28.nii.gz  transformed!
# pid_  465_2018-02-26.nii.gz  transformed!
# pid_  1186_2021-03-27.nii.gz  transformed!
# pid_  1092_2021-02-09.nii.gz  transformed!
# pid_  699_2020-07-07.nii.gz  transformed!
# pid_  134_2019-10-08.nii.gz  transformed!
# pid_  908_2020-03-26.nii.gz  transformed!
# pid_  150_2019-09-18.nii.gz  transformed!
# pid_  816_2020-08-20.nii.gz  transformed!
# pid_  1315_2021-05-30.nii.gz  transformed!
# pid_  648_2020-05-27.nii.gz  transformed!
# pid_  1303_2021-05-30.nii.gz  transformed!
# pid_  423_2018-10-23.nii.gz  transformed!
# pid_  973_2020-04-15.nii.gz  transformed!
# pid_  1053_2019-04-18.nii.gz  transformed!
# pid_  106_2019-09-20.nii.gz  transformed!
# pid_  1073_2020-11-26.nii.gz  transformed!
# pid_  66_2019-08-15.nii.gz  transformed!
# pid_  812_2021-04-01.nii.gz  transformed!
# pid_  1571_2021-09-04.nii.gz  transformed!
# pid_  1131_2021-03-18.nii.gz  transformed!
# pid_  224_2019-11-26.nii.gz  transformed!
# pid_  789_2020-08-17.nii.gz  transformed!
# pid_  888_2020-10-08.nii.gz  transformed!
# pid_  1527_2018-07-27.nii.gz  transformed!
# pid_  426_2019-04-16.nii.gz  transformed!
# pid_  517_2018-01-26.nii.gz  transformed!
# pid_  1525_2018-03-02.nii.gz  transformed!
# pid_  315_2019-07-19.nii.gz  transformed!
# pid_  630_2020-05-18.nii.gz  transformed!
# pid_  88_2019-09-18.nii.gz  transformed!
# pid_  1314_2021-06-02.nii.gz  transformed!
# pid_  719_2020-07-08.nii.gz  transformed!
# pid_  930_2020-10-24.nii.gz  transformed!
# pid_  1255_2020-10-29.nii.gz  transformed!
# pid_  1241_2021-04-28.nii.gz  transformed!
# pid_  568_2019-02-28.nii.gz  transformed!
# pid_  1280_2021-05-11.nii.gz  transformed!
# pid_  829_2020-09-04.nii.gz  transformed!
# pid_  1014_2020-12-17.nii.gz  transformed!
# pid_  1422_2021-05-11.nii.gz  transformed!
# pid_  1313_2021-06-10.nii.gz  transformed!
# pid_  41_2019-05-17.nii.gz  transformed!
# pid_  833_2020-09-04.nii.gz  transformed!
# pid_  706_2020-06-29.nii.gz  transformed!
# pid_  944_2020-11-04.nii.gz  transformed!
# pid_  613_2020-05-04.nii.gz  transformed!
# pid_  360_2020-04-16.nii.gz  transformed!
# pid_  435_2019-02-14.nii.gz  transformed!
# pid_  1367_2021-06-16.nii.gz  transformed!
# pid_  883_2020-09-23.nii.gz  transformed!
# pid_  1585_2021-11-01.nii.gz  transformed!
# pid_  1031_2020-11-19.nii.gz  transformed!
# pid_  1095_2021-01-21.nii.gz  transformed!
# pid_  1541_2018-01-11.nii.gz  transformed!
# pid_  493_2018-06-21.nii.gz  transformed!
# pid_  1180_2021-03-26.nii.gz  transformed!
# pid_  124_2019-09-25.nii.gz  transformed!
# pid_  1644_2021-05-31.nii.gz  transformed!
# pid_  697_2020-07-06.nii.gz  transformed!
# pid_  983_2020-11-20.nii.gz  transformed!
# pid_  998_2020-12-04.nii.gz  transformed!
# pid_  215_2019-11-20.nii.gz  transformed!
# pid_  575_2018-07-11.nii.gz  transformed!
# pid_  904_2020-08-20.nii.gz  transformed!
# pid_  747_2020-12-02.nii.gz  transformed!
# pid_  1056_2020-11-27.nii.gz  transformed!
# pid_  264_2019-11-28.nii.gz  transformed!
# pid_  680_2020-04-08.nii.gz  transformed!
# pid_  715_2020-07-03.nii.gz  transformed!
# pid_  429_2019-04-29.nii.gz  transformed!
# pid_  332_2020-03-18.nii.gz  transformed!
# pid_  428_2019-02-19.nii.gz  transformed!
# pid_  156_2019-10-29.nii.gz  transformed!
# pid_  1225_2021-04-20.nii.gz  transformed!
# pid_  1366_2021-06-22.nii.gz  transformed!
# pid_  1182_2021-03-24.nii.gz  transformed!
# pid_  1007_2020-12-05.nii.gz  transformed!
# pid_  593_2018-06-12.nii.gz  transformed!
# pid_  26_2019-04-04.nii.gz  transformed!
# pid_  1_2018-04-12.nii.gz  transformed!
# pid_  709_2020-03-20.nii.gz  transformed!
# pid_  1257_2021-05-06.nii.gz  transformed!
# pid_  154_2019-10-10.nii.gz  transformed!

# %%
if __name__ == '__main__':
    baseDir = r'/home/konata/Dataset/TED_MRI/T2/mask/origin_slice/testx4'
    objDir = '/home/konata/Dataset/TED_MRI/T2/mask/origin_slice/testx4re'
    outspacing_0 = 0.3093*4
    outspacing_1 = 0.3093*4
    outspacing_2 = 3.85
    
    #I_vol_list = ['reg_ADC.nii.gz', 'reg_DWI_0.nii.gz', 'reg_DWI_800.nii.gz', 'reg_T1C.nii.gz', 'T2.nii.gz']
 
    if os.path.exists(baseDir):

        imgs_list = os.listdir(baseDir)

        for img in imgs_list:
            #if img in I_vol_list:
            img_dir = baseDir +'/' + img
            resampled_img_dir = objDir +'/'+ img

            img_ori = sitk.Image(sitk.ReadImage(img_dir))
            img_ori_spacing = img_ori.GetSpacing()
            #outspacing_2 = img_ori_spacing[2]
            outspacing = [outspacing_0, outspacing_1, outspacing_2]

            img_resampled = resampleVolume(outspacing, img_ori)
            sitk.WriteImage(img_resampled, resampled_img_dir)
            print('pid_ ', img, ' transformed!')
# Out:
# pid_  637_2020-05-11.nii.gz  transformed!
# pid_  683_2020-06-16.nii.gz  transformed!
# pid_  430_2019-04-09.nii.gz  transformed!
# pid_  681_2020-06-12.nii.gz  transformed!
# pid_  440_2018-11-29.nii.gz  transformed!
# pid_  1656_2021-05-13.nii.gz  transformed!
# pid_  36_2019-05-09.nii.gz  transformed!
# pid_  740_2020-07-13.nii.gz  transformed!
# pid_  886_2020-08-06.nii.gz  transformed!
# pid_  1142_2021-03-04.nii.gz  transformed!
# pid_  516_2018-02-13.nii.gz  transformed!
# pid_  199_2019-05-16.nii.gz  transformed!
# pid_  1265_2021-05-07.nii.gz  transformed!
# pid_  748_2020-08-03.nii.gz  transformed!
# pid_  482_2018-11-08.nii.gz  transformed!
# pid_  460_2017-10-20.nii.gz  transformed!
# pid_  1645_2021-05-15.nii.gz  transformed!
# pid_  495_2019-06-18.nii.gz  transformed!
# pid_  788_2020-08-14.nii.gz  transformed!
# pid_  976_2020-11-13.nii.gz  transformed!
# pid_  1247_2021-02-19.nii.gz  transformed!
# pid_  1248_2021-05-04.nii.gz  transformed!
# pid_  570_2018-05-30.nii.gz  transformed!
# pid_  1520_2021-05-30.nii.gz  transformed!
# pid_  1015_2021-03-23.nii.gz  transformed!
# pid_  1630_2021-05-11.nii.gz  transformed!
# pid_  522_2019-01-30.nii.gz  transformed!
# pid_  162_2019-08-15.nii.gz  transformed!
# pid_  391_2018-02-08.nii.gz  transformed!
# pid_  1477_2021-09-18.nii.gz  transformed!
# pid_  198_2019-11-20.nii.gz  transformed!
# pid_  1668_2021-06-26.nii.gz  transformed!
# pid_  984_2020-11-19.nii.gz  transformed!
# pid_  653_2019-12-04.nii.gz  transformed!
# pid_  452_2018-11-20.nii.gz  transformed!
# pid_  443_2019-03-21.nii.gz  transformed!
# pid_  336_2020-03-26.nii.gz  transformed!
# pid_  127_2019-09-04.nii.gz  transformed!
# pid_  673_2020-06-05.nii.gz  transformed!
# pid_  1093_2021-02-09.nii.gz  transformed!
# pid_  191_2019-11-20.nii.gz  transformed!
# pid_  992_2020-11-12.nii.gz  transformed!
# pid_  1657_2021-07-06.nii.gz  transformed!
# pid_  1385_2021-06-28.nii.gz  transformed!
# pid_  465_2018-02-26.nii.gz  transformed!
# pid_  1186_2021-03-27.nii.gz  transformed!
# pid_  1092_2021-02-09.nii.gz  transformed!
# pid_  699_2020-07-07.nii.gz  transformed!
# pid_  134_2019-10-08.nii.gz  transformed!
# pid_  908_2020-03-26.nii.gz  transformed!
# pid_  150_2019-09-18.nii.gz  transformed!
# pid_  816_2020-08-20.nii.gz  transformed!
# pid_  1315_2021-05-30.nii.gz  transformed!
# pid_  648_2020-05-27.nii.gz  transformed!
# pid_  1303_2021-05-30.nii.gz  transformed!
# pid_  423_2018-10-23.nii.gz  transformed!
# pid_  973_2020-04-15.nii.gz  transformed!
# pid_  1053_2019-04-18.nii.gz  transformed!
# pid_  106_2019-09-20.nii.gz  transformed!
# pid_  1073_2020-11-26.nii.gz  transformed!
# pid_  66_2019-08-15.nii.gz  transformed!
# pid_  812_2021-04-01.nii.gz  transformed!
# pid_  1571_2021-09-04.nii.gz  transformed!
# pid_  1131_2021-03-18.nii.gz  transformed!
# pid_  224_2019-11-26.nii.gz  transformed!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_30904/3613528045.py in ?()
#      15             #if img in I_vol_list:
#      16             img_dir = baseDir +'/' + img
#      17             resampled_img_dir = objDir +'/'+ img
#      18
# ---> 19             img_ori = sitk.Image(sitk.ReadImage(img_dir))
#      20             img_ori_spacing = img_ori.GetSpacing()
#      21             #outspacing_2 = img_ori_spacing[2]
#      22             outspacing = [outspacing_0, outspacing_1, outspacing_2]
#
# ~/anaconda3/envs/preprocess/lib/python3.9/site-packages/SimpleITK/extra.py in ?(fileName, outputPixelType, imageIO)
#     371         reader.SetFileNames([str(name) for name in fileName])
#     372
#     373     reader.SetImageIO(imageIO)
#     374     reader.SetOutputPixelType(outputPixelType)
# --> 375     return reader.Execute()
#
# ~/anaconda3/envs/preprocess/lib/python3.9/site-packages/SimpleITK/SimpleITK.py in ?(self)
#    8426         type to be same as the file. If the pixel type is specified then the itk::ConvertPixelBuffer will be used to convert the pixels.
#    8427
#    8428
#    8429         """
# -> 8430         return _SimpleITK.ImageFileReader_Execute(self)
#
# KeyboardInterrupt:
