# %%
import os
import pandas as pd

# %%
data=pd.read_excel('D:/data/TAO_MRI/T2/T2_radiomics.xlsx',sheet_name='T2_zuxueMRI')
#data=data.iloc[:,0:2]
img_list=os.listdir('/home/konata/Dataset/TED_MRI/TOM500/all_image')

# %%
for i in range(0,len(data)):
    if data.name[i] not in mask_list:
        data=data.drop(i)

# %%
data=data.reset_index(drop=True)
data
# Out:
#                        name  CAS  response  original_shape_Elongation  \
# 0     134_2019-10-08.nii.gz    1         0                   0.383197
# 1     976_2020-11-13.nii.gz    0         4                   0.394857
# 2     575_2018-07-11.nii.gz    1        19                   0.287495
# 3     452_2018-11-20.nii.gz    0        22                   0.310235
# 4    1186_2021-03-27.nii.gz    1        24                   0.375632
# ..                      ...  ...       ...                        ...
# 121  1520_2021-05-30.nii.gz    1       653                   0.374837
# 122   224_2019-11-26.nii.gz    1       656                   0.385691
# 123  1367_2021-06-16.nii.gz    1       661                   0.399046
# 124  1014_2020-12-17.nii.gz    0       662                   0.295834
# 125   495_2019-06-18.nii.gz    1       663                   0.330299
#
#      original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                   0.049024                        5.157371
# ...

# %%
cas=cas.drop(columns='index')

# %%
data.to_excel('T2_radiomics_gd.xlsx',sheet_name='T2_zuxueMRI',index=False)

# %%
img_list=os.listdir('/home/konata/Dataset/TED_MRI/TOM500/all_image')
pd.DataFrame(img_list).to_excel('/home/konata/Dataset/TED_MRI/TOM500/TOM500.xlsx',sheet_name='T2',index=False)
