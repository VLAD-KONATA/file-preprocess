# %%
import os
import shutil

# %%
trainDir=r'D:/data/BraTS2020/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/'
testDir=r'D:/data/BraTS2020/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/'

# %%
#train data
trainlist=os.listdir(trainDir)

for i in range(len(trainlist)):
    os.chdir(trainDir)
    if('BraTs20' in trainlist[i]):
        os.rename(trainlist[i],'slice0'+trainlist[i][-3:])
        
trainlist=os.listdir(trainDir)
for folder in trainlist:
    if('slice' in folder):
        trainfiles=os.listdir(trainDir+folder)
        for file in trainfiles:
            os.chdir(trainDir+folder)
            os.rename(file,file[21:])

# %%
#test data
testlist=os.listdir(testDir)
for i in range(len(testlist)):
    os.chdir(testDir)
    if('BraTS20' in testlist[i]):
        os.rename(testlist[i],'slice1'+testlist[i][-3:])
testlist=os.listdir(testDir)
for folder in testlist:
    if('slice' in folder):
        testfiles=os.listdir(testDir+folder)
        for file in testfiles:
            os.chdir(testDir+folder)
            os.rename(file,file[23:])

# %%
testlist
# Out:
# ['slice1001',
#  'slice1002',
#  'slice1003',
#  'slice1004',
#  'slice1005',
#  'slice1006',
#  'slice1007',
#  'slice1008',
#  'slice1009',
#  'slice1010',
#  'slice1011',
#  'slice1012',
#  'slice1013',
#  'slice1014',
#  'slice1015',
#  'slice1016',
#  'slice1017',
#  'slice1018',
#  'slice1019',
#  'slice1020',
#  'slice1021',
#  'slice1022',
#  'slice1023',
#  'slice1024',
#  'slice1025',
#  'slice1026',
#  'slice1027',
#  'slice1028',
#  'slice1029',
#  'slice1030',
#  'slice1031',
#  'slice1032',
#  'slice1033',
#  'slice1034',
#  'slice1035',
#  'slice1036',
#  'slice1037',
#  'slice1038',
#  'slice1039',
#  'slice1040',
#  'slice1041',
#  'slice1042',
#  'slice1043',
#  'slice1044',
#  'slice1045',
#  'slice1046',
#  'slice1047',
#  'slice1048',
#  'slice1049',
#  'slice1050',
#  'slice1051',
#  'slice1052',
#  'slice1053',
#  'slice1054',
#  'slice1055',
#  'slice1056',
#  'slice1057',
#  'slice1058',
#  'slice1059',
#  'slice1060',
#  'slice1061',
#  'slice1062',
#  'slice1063',
#  'slice1064',
#  'slice1065',
#  'slice1066',
#  'slice1067',
#  'slice1068',
#  'slice1069',
#  'slice1070',
#  'slice1071',
#  'slice1072',
#  'slice1073',
#  'slice1074',
#  'slice1075',
#  'slice1076',
#  'slice1077',
#  'slice1078',
#  'slice1079',
#  'slice1080',
#  'slice1081',
#  'slice1082',
#  'slice1083',
#  'slice1084',
#  'slice1085',
#  'slice1086',
#  'slice1087',
#  'slice1088',
#  'slice1089',
#  'slice1090',
#  'slice1091',
#  'slice1092',
#  'slice1093',
#  'slice1094',
#  'slice1095',
#  'slice1096',
#  'slice1097',
#  'slice1098',
#  'slice1099',
#  'slice1100',
#  'slice1101',
#  'slice1102',
#  'slice1103',
#  'slice1104',
#  'slice1105',
#  'slice1106',
#  'slice1107',
#  'slice1108',
#  'slice1109',
#  'slice1110',
#  'slice1111',
#  'slice1112',
#  'slice1113',
#  'slice1114',
#  'slice1115',
#  'slice1116',
#  'slice1117',
#  'slice1118',
#  'slice1119',
#  'slice1120',
#  'slice1121',
#  'slice1122',
#  'slice1123',
#  'slice1124',
#  'slice1125',
#  'slice1csv',
#  'slice1csv']
